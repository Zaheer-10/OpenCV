# %% [markdown]
# # How to Read, Write, Show Images in OpenCV

# %% [markdown]
# ## 1.Read Images

# %%
import cv2

# Read an image from a file
img = cv2.imread('opticalflow_lk.jpg', -1 )

print(img)
# Out:
# [[[141 125 108]
#   [138 124 106]
#   [137 126 112]
#   ...
#   [  2   1   0]
#   [  0   0   0]
#   [  0   0   0]]
#
#  [[141 125 108]
#   [138 124 106]
#   [138 127 113]
#   ...
#   [  2   1   0]
#   [  0   0   0]
#   [  0   0   0]]
#
#  [[142 126 109]
#   [138 124 106]
#   [138 127 113]
#   ...
#   [  2   1   0]
#   [  0   0   0]
#   [  0   0   0]]
#
#  ...
#
#  [[123 135 147]
#   [123 135 147]
#   [123 135 147]
#   ...
#   [  4   0   1]
#   [  2   0   0]
#   [  0   0   0]]
#
#  [[123 135 147]
#   [123 135 147]
#   [123 135 147]
#   ...
#   [  5   0   1]
#   [  2   0   0]
#   [  0   0   0]]
#
#  [[123 135 147]
#   [123 135 147]
#   [123 135 147]
#   ...
#   [ 10   2   3]
#   [  2   0   0]
#   [  0   0   0]]]

# %% [markdown]
# ## 2. Display the image in a window

# %%
display = cv2.imshow("First img" , img)
cv2.waitKey(0)
cv2.destroyAllWindows()

display

# %% [markdown]
# ## 3. Write image

# %%
cv2.imwrite('duplicate_opticalflow.jpg' , img)
# Out:
# True

# %% [markdown]
# ####  Let's say if the person want to close the pic only after the esc key and s key to save .

# %%
import cv2 

img = img = cv2.imread('opticalflow_lk.jpg', 1 )
cv2.imshow('image' , img)
k = cv2.waitKey(0)

if k == 27 :
    cv2.destroyAllWindows()
elif k == ord('s'):
    cv2.imwrite('dup2_opticalflow.jpg' , img)
    cv2.destroyAllWindows()

# %% [markdown]
# # Show vedios from camera

# %%
import cv2

cap = cv2.VideoCapture(0);

while(1):
    ret , frame = cap.read()
    cv2.imshow('Frame' , frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

        
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### Gray vedio/img

# %%
import cv2

cap = cv2.VideoCapture(0);

while(cap.isOpened()):
    ret , frame = cap.read()
    gray = cv2.cvtColor(frame , cv2.COLOR_BGR2GRAY)
    cv2.imshow('Frame' , gray)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

        
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture(0);
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('ouput.avi' ,  fourcc , 20.0 , (640 , 480))

print(cap.isOpened())
while(cap.isOpened()):
    ret , frame = cap.read()
    print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    print(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    out.write(frame)
    
    gray = cv2.cvtColor(frame , cv2.COLOR_BGR2GRAY)
    cv2.imshow('Frame' , gray)
    
   
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

        
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# True
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# 640.0
# 480.0
# ...
